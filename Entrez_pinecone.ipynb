# %% [markdown]
# # Entrez

# %% [markdown]
# ## 1. Installing required libraries

# %%
# !pip install sentencepiece transformers torch biopython cohere annoy pinecone-client -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 30.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 46.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
#   Building wheel for annoy (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import random
from google.colab import userdata
from pinecone import Pinecone, ServerlessSpec
import cohere
from annoy import AnnoyIndex
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config
from Bio import Entrez, Medline
from concurrent.futures import ThreadPoolExecutor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pinecone_api_key = "" #Add your pinecone API key here
cohere_api_key = "" #Add your cohere API key here

# %% [markdown]
# ## 2. Entrez
#
# I. Loading credentials
#
# II. Searching for articles / research papers based on keywords and publication date
#
# III. Fetching and saving articles from the PubMed database based on the following:
#
#
#
# * PMID
# * Title
# * Abstract
# * Authors
# * Author Affiliations
# * Author Keywords
# * Publication Title
# * Publication Year
#
# IV. Creating a Pandas dataframe to save the results
#
# V. Saving it to a csv file

# %%
Entrez.email =  userdata.get('enrez_email')
Entrez.api_key = userdata.get('enrez_key')

# %%
#ask user to select earliest publication date
publication_date = '2000/01/01'
retmax = 1000

unique_pmids = set()
keyword_dictionary_pmids = {}

keywords_list = ["diabetes", "cancer"]

for kw in keywords_list:
    search_term = kw
    handle = Entrez.esearch(db="pubmed", term=search_term, mindate=publication_date, retmax=retmax)
    record = Entrez.read(handle)
    handle.close()

    keyword_dictionary_pmids[kw] = record["IdList"]

    # Filter out PMIDs that have been already collected
    new_pmids = set(record["IdList"]) - unique_pmids

    print(f"{len(new_pmids)} new results found for Search '{kw}'")

    # Update the set of unique PMIDs
    unique_pmids.update(new_pmids)
# Out:
# 1000 new results found for Search 'diabetes'
# 972 new results found for Search 'cancer'

# %% [markdown]
# *Ask user to "add to basket" which of the result queries they wish to keep*
#
# *Transparent Search*

# %%
for keyword, pmid_list in keyword_dictionary_pmids.items():
    print(f"Search: {keyword}, \n PMIDs: {len(pmid_list)}")
    print()
# Out:
# Search: diabetes,
#  PMIDs: 1000
#
# Search: cancer,
#  PMIDs: 1000

# %% [markdown]
# *Or they can simply select all*

# %%
print(len(unique_pmids))
# Out:
# 1972

# %% [markdown]
# ### For Semantic Analysis we will use all

# %%
# Define a function to fetch article data
def fetch_article_data(pmid):
    try:
        handle = Entrez.efetch(db="pubmed", id=pmid, retmode="xml")
        record = Entrez.read(handle)
        handle.close()

        # Extract data as needed
        citation = record['PubmedArticle'][0]['MedlineCitation']
        keyword_list = citation.get('KeywordList', [])
        article = citation['Article']
        title = article.get('ArticleTitle', 'Title not available')

        # Check if the abstract is available
        abstract = None
        if 'Abstract' in article:
            abstract = article['Abstract']['AbstractText']
            abstract = ' '.join(abstract)

        # Extract author names & author affiliations
        author_list = article['AuthorList']
        affiliations = []
        authors = []
        for author in author_list:
            if 'LastName' in author and 'Initials' in author:
                full_name = f"{author['LastName']} {author['Initials']}"
                authors.append(full_name)
            if 'AffiliationInfo' in author:
                affiliation_info = author['AffiliationInfo']
                if len(affiliation_info):
                  affiliation_name_first = affiliation_info[0]
                  affiliations.append(affiliation_name_first.get('Affiliation', "Not available"))

        # Extract author keywords
        keywords = []
        if len(keyword_list):
          for keyword in keyword_list[0]:
            keywords.append(keyword)

        citation = record['PubmedArticle'][0]['MedlineCitation']
        journal_info = article['Journal']
        journal = journal_info.get('Title', 'Journal not available')
        issue = journal_info.get('JournalIssue', 'Journal issue not available')
        pub_date = issue.get('PubDate', 'PubDate not available')
        pub_year = pub_date.get('Year', 'Year not available')

        return {
            "PMID": pmid,
            "Title": title,
            "Abstract": abstract,
            "Authors": ['; '.join(authors)],
            "Author Affiliations": ['; '.join(affiliations)],
            "Author Keywords": [';'.join(keywords)],
            "Publication Title": journal,
            "Publication Year": pub_year,
        }

    except Exception as e:
        print(f"Error retrieving data for PMID {pmid}: {str(e)}")
        return None

# Specify the number of concurrent threads
num_threads = 5

# Use ThreadPoolExecutor for concurrent fetching
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Fetch article data concurrently
    results = list(executor.map(fetch_article_data, unique_pmids))

# Remove None values (articles with errors)
results = [result for result in results if result is not None]

# Create the DataFrame
df = pd.DataFrame(results)

# Print the resulting DataFrame
df.head()
# Out:
# Error retrieving data for PMID 38779496: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763052: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776926: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774394: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775477: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757094: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766432: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758819: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758687: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777442: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776803: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764060: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757245: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758129: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777812: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758678: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38761667: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776593: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779645: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777653: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775179: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770414: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778307: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776001: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764445: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780845: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774979: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778834: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776547: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774993: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778303: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778783: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758674: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765187: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774027: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775900: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762564: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774929: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757272: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758194: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778109: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779592: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776865: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765541: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778707: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769692: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777242: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778606: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765635: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765469: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774842: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779937: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779391: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777607: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779661: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775337: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768904: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763496: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777806: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771462: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779081: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779040: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776011: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775536: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779933: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778685: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771061: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774734: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779307: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775070: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774472: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778503: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773069: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768849: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756957: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765734: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775132: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774656: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779072: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780786: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773380: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774158: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762059: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778601: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38759826: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755663: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779515: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779867: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755956: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777864: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38761274: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774335: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773662: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763220: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776882: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780348: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774762: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768269: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762354: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780183: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764437: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768555: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763495: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778314: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780906: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775996: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775798: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756998: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774282: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775943: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777393: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778824: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758581: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774946: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757725: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760568: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774757: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764043: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765561: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38761084: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38772048: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766348: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779080: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776518: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776273: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777489: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770191: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780107: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776840: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771470: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776583: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778289: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779114: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779121: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38772891: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756426: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765344: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771473: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777403: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777763: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778174: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778252: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763446: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780100: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768222: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779463: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776169: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757394: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774125: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775545: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766659: 'AuthorList'
# Error retrieving data for PMID 38771336: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775683: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755602: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756423: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780943: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768125: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765485: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38775614: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 38780486: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776910: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758779: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38772989: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778767: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766421: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775919: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779252: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780953: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38767133: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765600: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765448: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778798: 'AuthorList'
# Error retrieving data for PMID 38778378: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776249: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778609: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38759850: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756309: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777037: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779752: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779703: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775835: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775035: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777540: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776693: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768367: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38772897: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776291: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780147: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779822: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771888: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769661: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777302: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765419: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762367: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775364: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777429: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775448: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776874: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762486: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777674: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771941: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774934: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778519: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776130: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778653: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774564: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778373: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776682: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775786: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780615: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778627: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770070: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778907: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780922: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756427: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774589: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768333: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756050: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777412: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779517: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779601: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779687: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757450: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762728: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758847: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769570: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780994: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775978: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769550: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778322: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779494: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758517: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776482: 'AuthorList'
# Error retrieving data for PMID 38769719: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777130: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775155: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38763780: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774568: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775415: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38761781: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766319: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38767101: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780956: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756007: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780990: 'AuthorList'
# Error retrieving data for PMID 38760383: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779095: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780130: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774943: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779739: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755442: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775809: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778911: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776020: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778429: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777537: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780115: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38761021: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777539: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775158: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777449: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780707: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777720: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765467: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770789: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765897: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762949: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757017: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775127: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760482: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770430: 'AuthorList'
# Error retrieving data for PMID 38778649: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780170: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773407: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38772502: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777309: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778121: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38767331: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755698: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768605: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777874: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778591: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780968: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777593: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766579: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768159: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758099: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774439: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779022: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775343: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760897: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775848: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775481: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775284: 'AuthorList'
# Error retrieving data for PMID 38775437: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779261: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778362: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762036: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38756291: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758346: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777445: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779875: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778374: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769229: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774819: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776556: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775784: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38765603: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777730: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773444: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777578: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38759306: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764377: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776636: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780518: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778217: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770366: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757633: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777129: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768336: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757431: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38767382: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776430: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775233: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769721: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 25905168: list index out of range
# Error retrieving data for PMID 38776382: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778555: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757569: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766817: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776913: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775935: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777699: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778641: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779948: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38766438: HTTP Error 429: Too Many RequestsError retrieving data for PMID 38777335: HTTP Error 429: Too Many Requests
#
# Error retrieving data for PMID 38768417: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38764722: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38758584: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775808: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38773581: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38769046: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775310: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778711: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38776577: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779358: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774772: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760126: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775238: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38759983: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775205: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768329: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38770017: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757326: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775562: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38759835: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778421: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771060: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778830: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778164: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38762325: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38768368: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778682: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777965: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38755684: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780425: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775215: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38760435: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777502: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38767251: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38777370: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778291: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779084: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38780085: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38779751: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38774541: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38757218: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38775844: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38771287: HTTP Error 429: Too Many Requests
# Error retrieving data for PMID 38778111: HTTP Error 429: Too Many Requests
#        PMID                                              Title  \
# 0  38780889  Changes in expression of breast cancer tumor b...
# 1  38776443  Recombinant ADAMTS13: an effective Rescue Ther...
# 2  38778679  [Trends, challenges, and reflections on early-...
# 3  38779178  Benefit-finding profiles and comparison of car...
# 4  38776638  SCOUT® Radar Localization at Time of Breast Bi...
#
#                                             Abstract  \
# 0  In metastatic breast cancer, differences in ex...
# 1                                               None
# 2  Early onset gastric cancer (EOGC), as a distin...
# 3  This study aimed to explore the benefit findin...
# 4  Evaluate surgical utilization of SCOUT reflect...
#
#                                              Authors  \
# 0  [Schwieger L; Postlewait LM; Liu Y; Jou S; Yi ...
# 1  [Dadoun SE; Adam K; Hensch L; Boyd TK; Ibrahim...
# 2                                  [Wang XF; Sun YH]
# 3                    [Lin X; Chen Z; Zhao Q; Zhou X]
# 4  [Dashevsky BZ; Muneer MS; Hao M; Liang T; Wapn...
#
#                                  Author Affiliations  \
# 0  [Division of Surgical Oncology, Department of ...
# 1  [Baylor College of Medicine, Houston, Texas, U...
# 2  [Department of General Surgery, Zhongshan Hosp...
# 3  [School of Nursing, Guangdong Pharmaceutical U...
# 4  [Department of Radiology, Stanford University ...
#
#                                      Author Keywords  \
# 0  [Breast cancer;Breast pathology;Hormone recept...
# 1                                                 []
# 2                                                 []
# 3  [Benefit finding;Cancer care quality;Cross-sec...
# 4  [breast biopsy;breast localization;breast ultr...
#
#                                    Publication Title Publication Year
# 0               Breast cancer research and treatment             2024
# 1                                     Blood advances             2024
# 2  Zhonghua wei chang wai ke za zhi = Chinese jou...             2024
# 3           Asia-Pacific journal of oncology nursing             2024
# 4                          Journal of breast imaging             2024

# %%
len(df)
# Out:
# 1590

# %%
df.head()
# Out:
#        PMID                                              Title  \
# 0  38780889  Changes in expression of breast cancer tumor b...
# 1  38776443  Recombinant ADAMTS13: an effective Rescue Ther...
# 2  38778679  [Trends, challenges, and reflections on early-...
# 3  38779178  Benefit-finding profiles and comparison of car...
# 4  38776638  SCOUT® Radar Localization at Time of Breast Bi...
#
#                                             Abstract  \
# 0  In metastatic breast cancer, differences in ex...
# 1                                               None
# 2  Early onset gastric cancer (EOGC), as a distin...
# 3  This study aimed to explore the benefit findin...
# 4  Evaluate surgical utilization of SCOUT reflect...
#
#                                              Authors  \
# 0  [Schwieger L; Postlewait LM; Liu Y; Jou S; Yi ...
# 1  [Dadoun SE; Adam K; Hensch L; Boyd TK; Ibrahim...
# 2                                  [Wang XF; Sun YH]
# 3                    [Lin X; Chen Z; Zhao Q; Zhou X]
# 4  [Dashevsky BZ; Muneer MS; Hao M; Liang T; Wapn...
#
#                                  Author Affiliations  \
# 0  [Division of Surgical Oncology, Department of ...
# 1  [Baylor College of Medicine, Houston, Texas, U...
# 2  [Department of General Surgery, Zhongshan Hosp...
# 3  [School of Nursing, Guangdong Pharmaceutical U...
# 4  [Department of Radiology, Stanford University ...
#
#                                      Author Keywords  \
# 0  [Breast cancer;Breast pathology;Hormone recept...
# 1                                                 []
# 2                                                 []
# 3  [Benefit finding;Cancer care quality;Cross-sec...
# 4  [breast biopsy;breast localization;breast ultr...
#
#                                    Publication Title Publication Year
# 0               Breast cancer research and treatment             2024
# 1                                     Blood advances             2024
# 2  Zhonghua wei chang wai ke za zhi = Chinese jou...             2024
# 3           Asia-Pacific journal of oncology nursing             2024
# 4                          Journal of breast imaging             2024

# %%
df.to_csv('entrez_data.csv')

# %% [markdown]
# ## 3. Restructuring and cleaning our data

# %%
df = pd.read_csv("entrez_data.csv")

# %%
df
# Out:
#       Unnamed: 0      PMID                                              Title  \
# 0              0  38780889  Changes in expression of breast cancer tumor b...
# 1              1  38776443  Recombinant ADAMTS13: an effective Rescue Ther...
# 2              2  38778679  [Trends, challenges, and reflections on early-...
# 3              3  38779178  Benefit-finding profiles and comparison of car...
# 4              4  38776638  SCOUT® Radar Localization at Time of Breast Bi...
# ...          ...       ...                                                ...
# 1585        1585  38778887  Complex Regional Pain Syndrome in Cancer Cases...
# 1586        1586  38775859  Mapping the Single-cell Differentiation Landsc...
# 1587        1587  38774165  Poor Glycemic Control Affecting Screening of P...
# 1588        1588  38776225  The C-terminal disordered loop domain of Apc8 ...
# 1589        1589  38772586  Breaking down barriers to bariatric care: a qu...
#
#                                                Abstract  \
# 0     In metastatic breast cancer, differences in ex...
# 1                                                   NaN
# 2     Early onset gastric cancer (EOGC), as a distin...
# 3     This study aimed to explore the benefit findin...
# 4     Evaluate surgical utilization of SCOUT reflect...
# ...                                                 ...
# 1585  Complex regional pain syndrome (CRPS) is a dis...
# 1586  The genetic intratumoral heterogeneity observe...
# 1587  Introduction Diabetes and cancer are commonly ...
# 1588  The anaphase-promoting complex/cyclosome (APC/...
# 1589  Telemedicine is becoming an increasingly feasi...
#
#                                                 Authors  \
# 0     ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...
# 1     ['Dadoun SE; Adam K; Hensch L; Boyd TK; Ibrahi...
# 2                                   ['Wang XF; Sun YH']
# 3                     ['Lin X; Chen Z; Zhao Q; Zhou X']
# 4     ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...
# ...                                                 ...
# 1585      ['Thanaboriboon C; Matos Macêdo MC; Perez J']
# 1586  ['Truong DD; Weistuch C; Murgas KA; Admane P; ...
# 1587  ['Bharti A; Shekhar R; Prakash P; Kumari S; Ku...
# 1588  ['Darling S; Fujimitsu K; Chia KH; Zou J; Rapp...
# 1589  ['Poljo A; Tynes DM; Timper K; Süsstrunk J; Kr...
#
#                                     Author Affiliations  \
# 0     ['Division of Surgical Oncology, Department of...
# 1     ["Baylor College of Medicine, Houston, Texas, ...
# 2     ['Department of General Surgery, Zhongshan Hos...
# 3     ['School of Nursing, Guangdong Pharmaceutical ...
# 4     ['Department of Radiology, Stanford University...
# ...                                                 ...
# 1585  ['Cancer Pain Clinic, Departments of Anesthesi...
# 1586  ['The University of Texas MD Anderson Cancer C...
# 1587  ['Biochemistry, Indira Gandhi Institute of Med...
# 1588  ['Cell Cycle Control Group, University College...
# 1589  ['Department of Visceral Surgery, Clarunis, Un...
#
#                                         Author Keywords  \
# 0     ['Breast cancer;Breast pathology;Hormone recep...
# 1                                                  ['']
# 2                                                  ['']
# 3     ['Benefit finding;Cancer care quality;Cross-se...
# 4     ['breast biopsy;breast localization;breast ult...
# ...                                                 ...
# 1585                          ['CRPS;cancer;causalgia']
# 1586                                               ['']
# 1587  ['carcinoma prostrate;diabetes mellitus;glycat...
# 1588  ['APC/C;CDK;CP: Molecular biology;Cdc20;Cks;ce...
# 1589  ['bariatric surgery;health informatics;qualita...
#
#                                       Publication Title Publication Year
# 0                  Breast cancer research and treatment             2024
# 1                                        Blood advances             2024
# 2     Zhonghua wei chang wai ke za zhi = Chinese jou...             2024
# 3              Asia-Pacific journal of oncology nursing             2024
# 4                             Journal of breast imaging             2024
# ...                                                 ...              ...
# 1585         International medical case reports journal             2024
# 1586  Clinical cancer research : an official journal...             2024
# 1587                                             Cureus             2024
# 1588                                       Cell reports             2024
# 1589                                           BMJ open             2024
#
# [1590 rows x 9 columns]

# %%
df.head()
# Out:
#    Unnamed: 0      PMID                                              Title  \
# 0           0  38780889  Changes in expression of breast cancer tumor b...
# 1           1  38776443  Recombinant ADAMTS13: an effective Rescue Ther...
# 2           2  38778679  [Trends, challenges, and reflections on early-...
# 3           3  38779178  Benefit-finding profiles and comparison of car...
# 4           4  38776638  SCOUT® Radar Localization at Time of Breast Bi...
#
#                                             Abstract  \
# 0  In metastatic breast cancer, differences in ex...
# 1                                                NaN
# 2  Early onset gastric cancer (EOGC), as a distin...
# 3  This study aimed to explore the benefit findin...
# 4  Evaluate surgical utilization of SCOUT reflect...
#
#                                              Authors  \
# 0  ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...
# 1  ['Dadoun SE; Adam K; Hensch L; Boyd TK; Ibrahi...
# 2                                ['Wang XF; Sun YH']
# 3                  ['Lin X; Chen Z; Zhao Q; Zhou X']
# 4  ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...
#
#                                  Author Affiliations  \
# 0  ['Division of Surgical Oncology, Department of...
# 1  ["Baylor College of Medicine, Houston, Texas, ...
# 2  ['Department of General Surgery, Zhongshan Hos...
# 3  ['School of Nursing, Guangdong Pharmaceutical ...
# 4  ['Department of Radiology, Stanford University...
#
#                                      Author Keywords  \
# 0  ['Breast cancer;Breast pathology;Hormone recep...
# 1                                               ['']
# 2                                               ['']
# 3  ['Benefit finding;Cancer care quality;Cross-se...
# 4  ['breast biopsy;breast localization;breast ult...
#
#                                    Publication Title Publication Year
# 0               Breast cancer research and treatment             2024
# 1                                     Blood advances             2024
# 2  Zhonghua wei chang wai ke za zhi = Chinese jou...             2024
# 3           Asia-Pacific journal of oncology nursing             2024
# 4                          Journal of breast imaging             2024

# %%
df.tail()
# Out:
#       Unnamed: 0      PMID                                              Title  \
# 1585        1585  38778887  Complex Regional Pain Syndrome in Cancer Cases...
# 1586        1586  38775859  Mapping the Single-cell Differentiation Landsc...
# 1587        1587  38774165  Poor Glycemic Control Affecting Screening of P...
# 1588        1588  38776225  The C-terminal disordered loop domain of Apc8 ...
# 1589        1589  38772586  Breaking down barriers to bariatric care: a qu...
#
#                                                Abstract  \
# 1585  Complex regional pain syndrome (CRPS) is a dis...
# 1586  The genetic intratumoral heterogeneity observe...
# 1587  Introduction Diabetes and cancer are commonly ...
# 1588  The anaphase-promoting complex/cyclosome (APC/...
# 1589  Telemedicine is becoming an increasingly feasi...
#
#                                                 Authors  \
# 1585      ['Thanaboriboon C; Matos Macêdo MC; Perez J']
# 1586  ['Truong DD; Weistuch C; Murgas KA; Admane P; ...
# 1587  ['Bharti A; Shekhar R; Prakash P; Kumari S; Ku...
# 1588  ['Darling S; Fujimitsu K; Chia KH; Zou J; Rapp...
# 1589  ['Poljo A; Tynes DM; Timper K; Süsstrunk J; Kr...
#
#                                     Author Affiliations  \
# 1585  ['Cancer Pain Clinic, Departments of Anesthesi...
# 1586  ['The University of Texas MD Anderson Cancer C...
# 1587  ['Biochemistry, Indira Gandhi Institute of Med...
# 1588  ['Cell Cycle Control Group, University College...
# 1589  ['Department of Visceral Surgery, Clarunis, Un...
#
#                                         Author Keywords  \
# 1585                          ['CRPS;cancer;causalgia']
# 1586                                               ['']
# 1587  ['carcinoma prostrate;diabetes mellitus;glycat...
# 1588  ['APC/C;CDK;CP: Molecular biology;Cdc20;Cks;ce...
# 1589  ['bariatric surgery;health informatics;qualita...
#
#                                       Publication Title Publication Year
# 1585         International medical case reports journal             2024
# 1586  Clinical cancer research : an official journal...             2024
# 1587                                             Cureus             2024
# 1588                                       Cell reports             2024
# 1589                                           BMJ open             2024

# %%
df["Publication Year"].min()
# Out:
# '2023'

# %%
df["Publication Year"] = df["Publication Year"].str.replace('Year not available', '2024')

# %%
df["Publication Year"].max()
# Out:
# '2024'

# %%
column_list = [column for column in df.columns]
print(column_list)
# Out:
# ['Unnamed: 0', 'PMID', 'Title', 'Abstract', 'Authors', 'Author Affiliations', 'Author Keywords', 'Publication Title', 'Publication Year']

# %%
for column in df.columns:
    if column in ["PMID", "Author Affiliations", "Publication Title", "Author Keywords"]:
        df.pop(column)

# %%
df.dropna(subset=['Abstract'])
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Changes in expression of breast cancer tumor b...
# 2              2  [Trends, challenges, and reflections on early-...
# 3              3  Benefit-finding profiles and comparison of car...
# 4              4  SCOUT® Radar Localization at Time of Breast Bi...
# 5              5  Factors Associated with Patient Education in P...
# ...          ...                                                ...
# 1585        1585  Complex Regional Pain Syndrome in Cancer Cases...
# 1586        1586  Mapping the Single-cell Differentiation Landsc...
# 1587        1587  Poor Glycemic Control Affecting Screening of P...
# 1588        1588  The C-terminal disordered loop domain of Apc8 ...
# 1589        1589  Breaking down barriers to bariatric care: a qu...
#
#                                                Abstract  \
# 0     In metastatic breast cancer, differences in ex...
# 2     Early onset gastric cancer (EOGC), as a distin...
# 3     This study aimed to explore the benefit findin...
# 4     Evaluate surgical utilization of SCOUT reflect...
# 5     Patient education in chronic obstructive pulmo...
# ...                                                 ...
# 1585  Complex regional pain syndrome (CRPS) is a dis...
# 1586  The genetic intratumoral heterogeneity observe...
# 1587  Introduction Diabetes and cancer are commonly ...
# 1588  The anaphase-promoting complex/cyclosome (APC/...
# 1589  Telemedicine is becoming an increasingly feasi...
#
#                                                 Authors Publication Year
# 0     ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...             2024
# 2                                   ['Wang XF; Sun YH']             2024
# 3                     ['Lin X; Chen Z; Zhao Q; Zhou X']             2024
# 4     ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...             2024
# 5     ['Lindh A; Giezeman M; Theander K; Zakrisson A...             2024
# ...                                                 ...              ...
# 1585      ['Thanaboriboon C; Matos Macêdo MC; Perez J']             2024
# 1586  ['Truong DD; Weistuch C; Murgas KA; Admane P; ...             2024
# 1587  ['Bharti A; Shekhar R; Prakash P; Kumari S; Ku...             2024
# 1588  ['Darling S; Fujimitsu K; Chia KH; Zou J; Rapp...             2024
# 1589  ['Poljo A; Tynes DM; Timper K; Süsstrunk J; Kr...             2024
#
# [1467 rows x 5 columns]

# %%
df.to_csv("cleaned_entrez.csv", index = False)

# %% [markdown]
# ## 4. Summarization (based on Transformers and Tokenizers)

# %%
df = pd.read_csv("cleaned_entrez.csv")

# %%
model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
device = torch.device('cpu')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
for abstract in df['Abstract']:
    print("-----------")
    text = str(abstract)
    preprocessed_text = text.strip().replace('\n','')
    t5_input_text = 'summarize: ' + preprocessed_text
    tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=300).to(device)
    summary_ids = model.generate(tokenized_text, min_length=30, max_length=300)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    print("Abstract: ",abstract,"\n", "Summary: ", summary)
# Out:
# -----------
# Abstract:  In metastatic breast cancer, differences in expression patterns of estrogen receptor (ER), progesterone receptor (PR), and human epidermal growth factor receptor-2 (HER2) between the primary tumor (PT) and metastatic site (MET) have been reported. However, there is limited understanding of the relationship of tumor subtype discordance and overall survival (OS). We evaluated patterns of ER/PR/HER2 in PTs and corresponding METs and assessed the relationship between these patterns and OS. Patients diagnosed at our center with metastatic breast cancer (2011-2020) were included. ER/PR were stratified as < 1%/1-10%/ > 10% by immunohistochemistry and HER2 as positive/negative by immunohistochemistry/FISH. Tumor subtypes were classified as ER or PR + /HER2-, HER2+ , or triple-negative. Biomarker discordance data from PTs to METs were analyzed for expression patterns. OS was assessed. Of 254 patients, 41 (16.1%) had synchronous and 213 (83.9%) had metachronous METs. Category change of ER/PR/HER2 expression was observed in 56 (22.0%), 117 (40.5%), and 30 (11.8%) patients, respectively. Tumor subtype changed in 56 (22.0%) patients. We identified a difference between PT and MET from ER > 10% to ER < 1% (n = 28,16.2% p < 0.01); PR > 10% to PR < 1% (n = 54,48.2%, p < 0.001); PR > 10% to PR 1-10% (n = 18,16.1%, p < 0.001), and ER or PR+/HER2- to triple-negative (n = 19,13.0%, p = 0.03). In log-rank analysis, change from an ER or PR+/HER2- (5-year OS 88.6%) PT to a HER2+(67.5%) or triple-negative (54.6%) MET was associated with decreased survival (p < 0.01); however, in multivariate analysis, discordant biomarker expression was not associated with decreased survival (p > 0.05). Tumor expression of ER/PR/HER2 can differ between the PT and MET. Loss of ER/PR expression is common and may be related to worse survival. Routine assessment of MET tumor markers could inform prognosis and therapeutic decision-making.
#  Summary:  differences in expression patterns of estrogen receptor (ER), progesterone receptor (PR) and human epidermal growth factor receptor-2 (HER2) between primary tumor and metastatic site (MET) have been reported. there is limited understanding of the relationship of tumor subtype discordance and overall survival (OS)
# -----------
# Abstract:  nan
#  Summary:  nan. nan. nan.. nan.. nan.
# -----------
# Abstract:  Early onset gastric cancer (EOGC), as a distinct type of gastric cancer, has seen a gradually increasing incidence in recent years, imposing significant negative impacts on society and families, and has attracted widespread attention. EOGC presents a series of clinical characteristics, such as a higher prevalence among women, pathological types predominantly being poorly differentiated or undifferentiated, and Lauren classification often being diffuse, making it more prone to distant metastasis. However, the causes and mechanisms of its onset are not yet fully understood. Notably, about 10% of EOGC cases exhibit familial clustering and germline mutations in the Cadherin-1 (CDH1) or α-1 catenin (CTNNA1) genes, known as hereditary diffuse gastric cancer (HDGC). These unique clinical features pose significant challenges for the diagnosis and treatment of EOGC. The core of treatment for early onset gastric cancer focuses on strong efficacy, function preservation, rehabilitation, and social reintegration. Clinically, a multidisciplinary approach and comprehensive treatment are essential, with equal emphasis on physiological and psychological aspects, balancing therapeutic effectiveness with functional outcomes, to benefit more patients with EOGC.
#  Summary:  EOGC has seen a gradually increasing incidence in recent years. pathological types predominantly being poorly differentiated or undifferentiated. about 10% of EOGC cases exhibit familial clustering and germline mutations.
# -----------
# Abstract:  This study aimed to explore the benefit finding (BF) profiles among informal caregivers of patients with lung cancer, identify demographic and disease characteristics, and analyze differences in caregiving ability between profiles. This cross-sectional study utilized convenience sampling to select 272 informal caregivers of patients with lung cancer from a tertiary care hospital in Guangzhou, China. The research instruments used included the Demographic and Disease Characteristics Questionnaire, the revised version of the BF Scale, and the Chinese version of the Family Caregiver Task Inventory. Data analysis was performed using latent profile analysis, chi-square test, Fisher's exact probability test, Kruskal-Wallis test, and multivariate logistic regression. (1) BF can be divided into three profiles: "high benefit-family and personal growth" (Profile 1, 7.7%), "moderate benefit-unclear perception" (Profile 2, 44.9%), and "low benefit-coping ability deficient" (Profile 3, 47.4%). (2) Having a cocaregiver and a disease duration of 6-12 months were more likely to belong to Profile 1; caregivers of patients aged 40-60 years tended to belong to Profile 2; caregivers of older patients with disease duration > 12 months and clinical stage II or III were more likely to belong to Profile 3. (3) There were significant differences in the total score of caregiving ability and the scores of each dimension among the different BF profiles (<i>P</i> < 0.001), and the caregiving abilities of Profile 1 and Profile 2 were higher than those of Profile 3. There was heterogeneity in BF among informal caregivers of patients with lung cancer. Healthcare professionals can identify the key profiles of lung-cancer caregivers based on characteristics such as age, clinical stage, disease duration, and cocaregiver status and enhance their caregiving ability through targeted nursing guidance.
#  Summary:  study aimed to explore benefits finding profiles among informal caregivers of patients with lung cancer. a cross-sectional study used convenience sampling to select 272 informal caregivers. a study aimed to identify demographic and disease characteristics.
# -----------
# Abstract:  Evaluate surgical utilization of SCOUT reflectors placed at breast biopsy. Consent was waived for this retrospective IRB-approved, HIPAA-compliant study. Breast biopsy examinations that reported the term "SCOUT" between January 2021 and June 2022 were identified using an institutional search engine. Cases were included if a SCOUT reflector was placed at time of breast biopsy and excluded if lesion pathology was already known. Analysis was performed at the lesion level. A multivariate-regression analysis evaluated 6 variables with potential impact on SCOUT utilization. One hundred twenty-one lesions in 112 patients met inclusion criteria. Biopsy yielded 93% (113/121) malignant, 3% (4/121) elevated risk, 2% (2/121) benign-discordant, and 2% (2/121) benign-concordant results. Two cases lost to follow-up were excluded. SCOUT reflectors were utilized for lumpectomy (58%, 69/119 lesions) and excisional biopsy (6%, 7/119 lesions). SCOUTs were not utilized due to mastectomy (23%, 27/119), subsequent wire localization (2%, 2/119), and nonsurgical cases (12%, 14/119). Reflector placement utilization was 52% higher for findings less than 3.5 cm in size (P <.001), 33% higher in patients without prior treated breast cancer (P = .012), and 19% higher in patients with no suspicious ipsilateral lymph node (P = .048). SCOUT reflector placement at time of biopsy was utilized for surgery 64% (76/119) of the time, although most (98%, 119/121) biopsies were malignant, elevated risk, or benign-discordant. Factors increasing reflector utilization include smaller lesion size, no suspicious ipsilateral lymph node, and no prior treated breast cancer.
#  Summary:  biopsy examinations reported the term "SCOUT" between January 2021 and June 2022. a retrospective IRB-approved, HIPAA-compliant study was performed. a multivariate-regression analysis evaluated 6 variables with potential impact on SCOUT utilization.
# -----------
# Abstract:  Patient education in chronic obstructive pulmonary disease (COPD) is recommended in treatment strategy documents, since it can improve the ability to cope with the disease. Our aim was to identify the extent of and factors associated with patient education in patients with COPD in a primary health care setting. In this nationwide study, we identified 29,692 COPD patients with a registration in the Swedish National Airway Register (SNAR) in 2019. Data on patient education and other clinical variables of interest were collected from SNAR. The database was linked to additional national registers to obtain data about pharmacological treatment, exacerbations and educational level. Patient education had been received by 44% of COPD patients, 72% of whom had received education on pharmacological treatment including inhalation technique. A higher proportion of patients who had received education were offered smoking cessation support, had performed spirometry and answered the COPD Assessment Test (CAT), compared with patients without patient education. In the adjusted analysis, GOLD grade 2 (OR 1.29, 95% CI 1.18-1.42), grade 3 (OR 1.41, 95% CI 1.27-1.57) and grade 4 (OR 1.79, 95% CI 1.48-2.15), as well as GOLD group E (OR 1.17, 95% CI 1.06-1.29), ex-smoking (OR 1.70, 95% CI 1.56-1.84) and current smoking (OR 1.45, 95% CI 1.33-1.58) were positively associated with having received patient education, while cardiovascular disease (OR 0.92, 95% CI 0.87-0.98) and diabetes (OR 0.93, 95% CI 0.87-1.00) were negatively associated with receipt of patient education. Fewer than half of the patients had received patient education, and the education had mostly been given to those with more severe COPD, ex- and current smokers and patients with fewer comorbidities. Our study highlights the need to enhance patient education at an earlier stage of the disease.
#  Summary:  a nationwide study identified 29,692 COPD patients with a registration in the Swedish national airway register (SNAR) in 2019. the database was linked to additional national registers to obtain data about pharmacological treatment, exacerbations and educational level.
# -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cd9666bff09a> in <cell line: 1>()
#       5     t5_input_text = 'summarize: ' + preprocessed_text
#       6     tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=300).to(device)
# ----> 7     summary_ids = model.generate(tokenized_text, min_length=30, max_length=300)
#       8     summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#       9     print("Abstract: ",abstract,"\n", "Summary: ", summary)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1734
#    1735             # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1736             result = self._sample(
#    1737                 input_ids,
#    1738                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2373
#    2374             # forward pass to get next token
# -> 2375             outputs = self(
#    2376                 **model_inputs,
#    2377                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1738
#    1739         # Decode
# -> 1740         decoder_outputs = self.decoder(
#    1741             input_ids=decoder_input_ids,
#    1742             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1105                 )
#    1106             else:
# -> 1107                 layer_outputs = layer_module(
#    1108                     hidden_states,
#    1109                     attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     715                 query_length = None
#     716
# --> 717             cross_attention_outputs = self.layer[1](
#     718                 hidden_states,
#     719                 key_value_states=encoder_hidden_states,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     626     ):
#     627         normed_hidden_states = self.layer_norm(hidden_states)
# --> 628         attention_output = self.EncDecAttention(
#     629             normed_hidden_states,
#     630             mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     514
#     515         # get key/value states
# --> 516         key_states = project(
#     517             hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     518         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/modeling_t5.py in project(hidden_states, proj_layer, key_value_states, past_key_value)
#     499                     # (batch_size, n_heads, key_length, dim_per_head)
#     500                     hidden_states = torch.cat([past_key_value, hidden_states], dim=2)
# --> 501                 elif past_key_value.shape[2] != key_value_states.shape[1]:
#     502                     # checking that the `sequence_length` of the `past_key_value` is the same as
#     503                     # the provided `key_value_states` to support prefix tuning
#
# KeyboardInterrupt:

# %%
count = 0
# Define the summarization function
def summarize_text(text):
    global count
    count +=1
    if count == 2:
      print("Its working")
    if count%100 == 0:
      print(f"{count} summarized")

    # Check if the text is NaN (float) or None
    if pd.isna(text) or text is None:
        return ""  # Return an empty string for missing or None values
    preprocessed_text = str(text).strip().replace('\n', '')  # Convert to string and preprocess
    t5_input_text = 'summarize: ' + preprocessed_text
    tokenized_text = tokenizer.encode(
        t5_input_text,
        return_tensors='pt',
        max_length=350,
        truncation=True  # Explicitly enable truncation
    ).to(device)
    summary_ids = model.generate(tokenized_text, min_length=30, max_length=350)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

# Apply the summarization function to the "Abstract" column
df['Summarized'] = df['Abstract'].apply(summarize_text)

df.head()
# Out:
# Its working
# 100 summarized
# 200 summarized
# 300 summarized
# 400 summarized
# 500 summarized
# 600 summarized
# 700 summarized
# 800 summarized
# 900 summarized
# 1000 summarized
# 1100 summarized
# 1200 summarized
# 1300 summarized
# 1400 summarized
# 1500 summarized
#                                                Title  \
# 0  Changes in expression of breast cancer tumor b...
# 1  Recombinant ADAMTS13: an effective Rescue Ther...
# 2  [Trends, challenges, and reflections on early-...
# 3  Benefit-finding profiles and comparison of car...
# 4  SCOUT® Radar Localization at Time of Breast Bi...
#
#                                             Abstract  \
# 0  In metastatic breast cancer, differences in ex...
# 1                                                NaN
# 2  Early onset gastric cancer (EOGC), as a distin...
# 3  This study aimed to explore the benefit findin...
# 4  Evaluate surgical utilization of SCOUT reflect...
#
#                                              Authors  Publication Year  \
# 0  ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...              2024
# 1  ['Dadoun SE; Adam K; Hensch L; Boyd TK; Ibrahi...              2024
# 2                                ['Wang XF; Sun YH']              2024
# 3                  ['Lin X; Chen Z; Zhao Q; Zhou X']              2024
# 4  ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...              2024
#
#                                           Summarized
# 0  differences in expression patterns between pri...
# 1
# 2  EOGC has seen a gradually increasing incidence...
# 3  study aimed to explore benefit finding profile...
# 4  biopsy examinations reported the term "SCOUT" ...

# %%
df = df.replace(to_replace="", value=np.nan).dropna()

# %%
df = pd.read_csv("summarized_entrez.csv")
df.pop('Unnamed: 0')
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1585    1585
# 1586    1586
# 1587    1587
# 1588    1588
# 1589    1589
# Name: Unnamed: 0, Length: 1590, dtype: int64

# %%
df
# Out:
#                                                   Title  \
# 0     Changes in expression of breast cancer tumor b...
# 2     [Trends, challenges, and reflections on early-...
# 3     Benefit-finding profiles and comparison of car...
# 4     SCOUT® Radar Localization at Time of Breast Bi...
# 5     Factors Associated with Patient Education in P...
# ...                                                 ...
# 1585  Complex Regional Pain Syndrome in Cancer Cases...
# 1586  Mapping the Single-cell Differentiation Landsc...
# 1587  Poor Glycemic Control Affecting Screening of P...
# 1588  The C-terminal disordered loop domain of Apc8 ...
# 1589  Breaking down barriers to bariatric care: a qu...
#
#                                                Abstract  \
# 0     In metastatic breast cancer, differences in ex...
# 2     Early onset gastric cancer (EOGC), as a distin...
# 3     This study aimed to explore the benefit findin...
# 4     Evaluate surgical utilization of SCOUT reflect...
# 5     Patient education in chronic obstructive pulmo...
# ...                                                 ...
# 1585  Complex regional pain syndrome (CRPS) is a dis...
# 1586  The genetic intratumoral heterogeneity observe...
# 1587  Introduction Diabetes and cancer are commonly ...
# 1588  The anaphase-promoting complex/cyclosome (APC/...
# 1589  Telemedicine is becoming an increasingly feasi...
#
#                                                 Authors  Publication Year  \
# 0     ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...              2024
# 2                                   ['Wang XF; Sun YH']              2024
# 3                     ['Lin X; Chen Z; Zhao Q; Zhou X']              2024
# 4     ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...              2024
# 5     ['Lindh A; Giezeman M; Theander K; Zakrisson A...              2024
# ...                                                 ...               ...
# 1585      ['Thanaboriboon C; Matos Macêdo MC; Perez J']              2024
# 1586  ['Truong DD; Weistuch C; Murgas KA; Admane P; ...              2024
# 1587  ['Bharti A; Shekhar R; Prakash P; Kumari S; Ku...              2024
# 1588  ['Darling S; Fujimitsu K; Chia KH; Zou J; Rapp...              2024
# 1589  ['Poljo A; Tynes DM; Timper K; Süsstrunk J; Kr...              2024
#
#                                              Summarized
# 0     differences in expression patterns between pri...
# 2     EOGC has seen a gradually increasing incidence...
# 3     study aimed to explore benefit finding profile...
# 4     biopsy examinations reported the term "SCOUT" ...
# 5     a nationwide study identified 29,692 COPD pati...
# ...                                                 ...
# 1585  complex regional pain syndrome (CRPS) is a dis...
# 1586  a 'roadmap' of a human mesenchymal differentia...
# 1587  the link between diabetes and cancer is common...
# 1588  anaphase-promoting complex/cyclosome (APC/C) i...
# 1589  telemedicine is becoming an increasingly feasi...
#
# [1467 rows x 5 columns]

# %%
df.to_csv("new_entrez.csv", index = False)

# %% [markdown]
# ## 5. Cohere Embedding, Queries, and KNN

# %%
raw_df = pd.read_csv("/content/drive/MyDrive/entrez/new_entrez.csv")
print(raw_df.shape)
hq_df = raw_df
hq_df.head()
# Out:
# (1461, 5)
#                                                Title  \
# 0  Changes in expression of breast cancer tumor b...
# 1  [Trends, challenges, and reflections on early-...
# 2  Benefit-finding profiles and comparison of car...
# 3  SCOUT® Radar Localization at Time of Breast Bi...
# 4  Factors Associated with Patient Education in P...
#
#                                             Abstract  \
# 0  In metastatic breast cancer, differences in ex...
# 1  Early onset gastric cancer (EOGC), as a distin...
# 2  This study aimed to explore the benefit findin...
# 3  Evaluate surgical utilization of SCOUT reflect...
# 4  Patient education in chronic obstructive pulmo...
#
#                                              Authors  Publication Year  \
# 0  ['Schwieger L; Postlewait LM; Liu Y; Jou S; Yi...              2024
# 1                                ['Wang XF; Sun YH']              2024
# 2                  ['Lin X; Chen Z; Zhao Q; Zhou X']              2024
# 3  ['Dashevsky BZ; Muneer MS; Hao M; Liang T; Wap...              2024
# 4  ['Lindh A; Giezeman M; Theander K; Zakrisson A...              2024
#
#                                              Summary
# 0  differences in expression patterns between pri...
# 1  EOGC has seen a gradually increasing incidence...
# 2  study aimed to explore benefit finding profile...
# 3  biopsy examinations reported the term "SCOUT" ...
# 4  a nationwide study identified 29,692 COPD pati...

# %%
hq_df.shape
# Out:
# (1461, 5)

# %%
df = hq_df

# %%
# Print a few sample documents
texts = hq_df["Summary"].tolist()

random.seed(100)
for item in random.sample(texts, 3):
  print(item)
# Out:
# nationwide cohort and mendelian randomisation analysis investigated link. a nationwide matched cohort used data from the Swedish ESPRESSO cohort. the association between persistent villous atrophy and type 2 diabetes remains undetermined.
# AMP facilitated wound healing in vivo. AMP inhibited pro-inflammatory factor secretions and inflammasome pathway.
# study aimed to explore association between SHR and all-cause mortality in the community-dwelling population. a total of 18 480 participants were included out of 82 091 from the NHANES 1999-2014 survey.

# %%
co = cohere.Client(cohere_api_key)

# %% [markdown]
# ### Creating and Storing Document Embeddings

# %%
response = co.embed(texts=texts, model='multilingual-22-12').embeddings
embeds = np.array(response)
# Embed the documents and store in index
search_index = AnnoyIndex(embeds.shape[1], 'angular')
# Add all the vectors to the search index
for i in range(len(embeds)):
    search_index.add_item(i, embeds[i])

search_index.build(100) # 10 trees
search_index.save('entrez_index.ann')
# Out:
# True

# %% [markdown]
# ### Defining Example Queries

# %%
queries = ["what are the symptoms of diabetes in females?"]

queries_lang = ["English"]

# %% [markdown]
# ### Returning results similar to given Queries (KNN)

# %%
results_list = []

for idx, q in enumerate(queries):

    # Retrieve the nearest neighbors
    query_embed = co.embed(texts=[q], model='multilingual-22-12').embeddings
    similar_item_ids, _ = search_index.get_nns_by_vector(query_embed[0], 5, include_distances=True)

    if len(similar_item_ids) >= 2:
        # Format the results
        results = pd.DataFrame(data={'Title': df.iloc[similar_item_ids[0]]['Title'],
                                     'Abstract': df.iloc[similar_item_ids[0]]['Abstract'],
                                     'Authors': df.iloc[similar_item_ids[0]]['Authors'],
                                     'Publication Year': df.iloc[similar_item_ids[0]]['Publication Year']}, index=[idx])

        results_list.append(results)
        print(f"Query:'{q}'\nNearest neighbors:")
        print(queries_lang[idx])
        print(results)
        print("\n")
    else:
        print("Not enough similar items found for query:", q)
# Out:
# Query:'what are the symptoms of diabetes in females?'
# Nearest neighbors:
# English
#                                                Title  \
# 0  Diabetes Distress Among the Roma Population Fr...
#
#                                             Abstract  \
# 0  Background Distress in patients with diabetes ...
#
#                                              Authors  Publication Year
# 0  ['Cosoreanu A; Rusu E; Mihai DA; Rusu F; Pante...              2024

# %% [markdown]
# ## 6. Pinecone Index and Final Results

# %% [markdown]
# ### Initialize the Pinecone Index

# %%
pc = Pinecone(pinecone_api_key)

# %%
index_name = 'entrez'

# if the index does not exist, we create it
if index_name not in pc.list_indexes().names():
   pc.create_index(
    index_name,
    dimension=shape[1], # Replace with your model dimensions
    metric="cosine", # Replace with your model metric
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
    )

# connect to index
index = pc.Index(index_name)

# %%
shape = np.array(embeds).shape
shape
# Out:
# (1461, 768)

# %% [markdown]
# ### Upsert the data into the Pinecone index

# %%
batch_size = 128

ids = [str(i) for i in range(shape[0])]
# create list of metadata dictionaries
meta = [{'Title': title, 'Abstract': abstract, 'Authors': authors, 'Publication Year': publication_year} for title, abstract, authors, publication_year in zip(df['Title'], df['Abstract'], df['Authors'], df['Publication Year'])]

# create list of (id, vector, metadata) tuples to be upserted
to_upsert = list(zip(ids, embeds, meta))

for i in range(0, shape[0], batch_size):
    i_end = min(i+batch_size, shape[0])
    index.upsert(vectors=to_upsert[i:i_end])

# let's view the index statistics
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 1792}},
#  'total_vector_count': 1792}

# %% [markdown]
# ### Return the results most similar to the query from the Pinecone index

# %%
query = "Are women with diabetes at higher risk for heart disease?"

# create the query embedding
xq = co.embed(
    texts=[query],
    model='multilingual-22-12',
    truncate='NONE'
).embeddings

print(np.array(xq).shape)

# query, returning the top 10 most similar results
res = index.query(vector=xq, top_k=10, include_metadata=True)
res
# Out:
# (1, 768)
# {'matches': [{'id': '362',
#               'metadata': {'Abstract': 'Type 2 diabetes mellitus (T2DM) is a '
#                                        'complex health issue include obesity, '
#                                        'high cholesterol, high blood pressure, '
#                                        'and chronic inflammation that increase '
#                                        'the risk of cardiovascular diseases '
#                                        '(CVDs). CVDs are of great concern in '
#                                        'the disease progression and prognosis '
#                                        'of T2DM. This review is a '
#                                        'comprehensive examination of the '
#                                        'literature on the relationship between '
#                                        'T2DM and cardiovascular risk, '
#                                        'nutrition-related cardiometabolic risk '
#                                        '(CMR) factors, and impact of dietary '
#                                        'modulations on CMR. In recent years '
#                                        'the researches has been focus on the '
#                                        'importance of a comprehensive '
#                                        'treatment approach like dietary '
#                                        'modulations to address multiple '
#                                        'cardiovascular risk reductions, '
#                                        'including hypertension and '
#                                        'dyslipidemia. Modulation of dietary '
#                                        'patterns are the most promising '
#                                        'interventions to prevent CMR factors '
#                                        'and T2DM via affecting the body '
#                                        'weight, glucose control, and microbial '
#                                        'diversity of individuals. Current '
#                                        'evidence suggests that high-quality '
#                                        'dietary patterns such as the Dietary '
#                                        'Approaches to Stop Hypertension (DASH) '
#                                        'eating plan and the Mediterranean diet '
#                                        'is important in the metabolic control '
#                                        'processes of T2DM with '
#                                        'anti-inflammatory and antioxidant '
#                                        'compounds, glucagon-like peptide '
#                                        'agonist compounds, and intestinal '
#                                        'microbiota changes. Nutrition plays a '
#                                        'critical role in preventing and '
#                                        'improving CVD outcomes in patients '
#                                        'with T2DM. Dietary modulations should '
#                                        'be planned considering individual '
#                                        'differences in responses to dietary '
#                                        'composition and nutritional changes, '
#                                        'personal preferences, eating behaviors '
#                                        'and gut microbiota differences.',
#                            'Authors': "['Dal N; Bilici S']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Dietary Modulations in Preventing '
#                                     'Cardiometabolic Risk in Individuals with '
#                                     'Type 2 Diabetes.'},
#               'score': 0.923353,
#               'values': []},
#              {'id': '235',
#               'metadata': {'Abstract': 'Hypertension prevalence among the '
#                                        'overall US adult population has been '
#                                        'relatively stable during the last two '
#                                        'decades. However, whether this '
#                                        'stabilization has occurred across '
#                                        'rural-urban communities and across '
#                                        'different geographic regions is '
#                                        'unknown, particularly among older '
#                                        'adults with diabetes who are likely to '
#                                        'have concomitant cardiovascular risk '
#                                        'factors. This serial cross-sectional '
#                                        'analysis used the 5% national sample '
#                                        'of Medicare administrative claims data '
#                                        '(n\u2009=\u20093,516,541) to examine '
#                                        'temporal trends (2005-2017) in '
#                                        'diagnosed hypertension among older '
#                                        'adults with diabetes, across '
#                                        'urban-rural communities and US census '
#                                        'regions (Northeast, Midwest, South, '
#                                        'and West). Joinpoint regression was '
#                                        'used to obtain annual percent change '
#                                        '(APC) in hypertension prevalence '
#                                        'across rural-urban communities and '
#                                        'geographic regions, and multivariable '
#                                        'adjusted regression was used to assess '
#                                        'associations between rural-urban '
#                                        'communities and hypertension '
#                                        'prevalence. The APC in the prevalence '
#                                        'of hypertension was higher during '
#                                        '2005-2010, and there was a slowdown in '
#                                        'the increase during 2011-2017 across '
#                                        'all regions, with significant '
#                                        'variations across rural-urban '
#                                        'communities within each of the '
#                                        'regions. In the regression analysis, '
#                                        'in the adjusted model, older adults '
#                                        'living in non-core (most rural) areas '
#                                        'in the Midwest (PR\u2009=\u20090.988, '
#                                        '95% CI: 0.981-0.995) and West (PR\u2009'
#                                        '=\u20090.935, 95% CI: 0.923-0.946) had '
#                                        'lower hypertension prevalence than '
#                                        'their regional counterparts living in '
#                                        'large central metro areas. Although '
#                                        'the magnitudes of these associations '
#                                        'are small, differences in hypertension '
#                                        'prevalence across rural-urban areas '
#                                        'and geographic regions may have '
#                                        'implications for targeted '
#                                        'interventions to improve chronic '
#                                        'disease prevention and management.',
#                            'Authors': "['Uddin J; Zhu S; Malla G; Levitan EB; "
#                                       "Rolka DB; Carson AP; Long DL']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Regional and rural-urban patterns in the '
#                                     'prevalence of diagnosed hypertension '
#                                     'among older U.S. adults with diabetes, '
#                                     '2005-2017.'},
#               'score': 0.912584484,
#               'values': []},
#              {'id': '394',
#               'metadata': {'Abstract': 'Diabetes is a metabolic disease '
#                                        'characterized by hyperglycemia, which '
#                                        'has increased the global medical '
#                                        'burden and is also the main cause of '
#                                        'death in most countries. To understand '
#                                        'the knowledge structure of global '
#                                        'development status, research focus, '
#                                        'and future trend of the relationship '
#                                        'between diabetes and metabolomics in '
#                                        'the past 20 years. The articles about '
#                                        'the relationship between diabetes and '
#                                        'metabolomics in the Web of Science '
#                                        'Core Collection were retrieved from '
#                                        '2002 to October 23, 2023, and the '
#                                        'relevant information was analyzed '
#                                        'using CiteSpace6.2.2R (CiteSpace), '
#                                        'VOSviewer6.1.18 (VOSviewer), and '
#                                        'Bibliometrix software under R '
#                                        'language. A total of 3123 publications '
#                                        'were included from 2002 to 2022. In '
#                                        'the past two decades, the number of '
#                                        'publications and citations in this '
#                                        'field has continued to increase. The '
#                                        'United States, China, Germany, the '
#                                        'United Kingdom, and other relevant '
#                                        'funds, institutions, and authors have '
#                                        'significantly contributed to this '
#                                        'field. <i>Scientific Reports</i> and '
#                                        '<i>PLoS One</i> are the journals with '
#                                        'the most publications and the most '
#                                        'citations. Through keyword '
#                                        'co-occurrence and cluster analysis, '
#                                        'the closely related keywords are '
#                                        '"insulin resistance", "risk", '
#                                        '"obesity", "oxidative stress", '
#                                        '"metabolomics", "metabolites" and '
#                                        '"biomarkers". Keyword clustering '
#                                        'included cardiovascular disease, gut '
#                                        'microbiota, metabonomics, diabetic '
#                                        'nephropathy, molecular docking, '
#                                        'gestational diabetes mellitus, '
#                                        'oxidative stress, and insulin '
#                                        'resistance. Burst detection analysis '
#                                        'of keyword depicted that "Gene", '
#                                        '"microbiota", "validation", "kidney '
#                                        'disease", "antioxidant activity", '
#                                        '"untargeted metabolomics", '
#                                        '"management", and "accumulation" are '
#                                        'knowledge frontiers in recent years. '
#                                        'The relationship between metabolomics '
#                                        'and diabetes is receiving extensive '
#                                        'attention. Diabetic nephropathy, '
#                                        'diabetic cardiovascular disease, and '
#                                        'kidney disease are key diseases for '
#                                        'future research in this field. Gut '
#                                        'microbiota, molecular docking, and '
#                                        'untargeted metabolomics are key '
#                                        'research directions in the future. '
#                                        'Antioxidant activity, gene, '
#                                        'validation, mass spectrometry, '
#                                        'management, and accumulation are at '
#                                        'the forefront of knowledge frontiers '
#                                        'in this field.',
#                            'Authors': "['Li H; Li L; Huang QQ; Yang SY; Zou "
#                                       "JJ; Xiao F; Xiang Q; Liu X; Yu R']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Global status and trends of metabolomics '
#                                     'in diabetes: A literature visualization '
#                                     'knowledge graph study.'},
#               'score': 0.912490129,
#               'values': []},
#              {'id': '542',
#               'metadata': {'Abstract': 'Osteoarthritis (OA) and diabetes '
#                                        'mellitus (DM) have long-term '
#                                        'deleterious chronic effects and are '
#                                        'among the most prevalent chronic '
#                                        'disorders. DM and its associated '
#                                        'factors, such as hyperglycemia, have a '
#                                        'significant contribution to the '
#                                        'pathophysiology of OA, particularly in '
#                                        'post-menopausal women. Women who have '
#                                        'uncontrolled diabetes (DM) are more '
#                                        'prone to develop osteoarthritis (OA), '
#                                        'which may be exacerbated by poor '
#                                        'glycemic control. Furthermore, this '
#                                        'category of female patients with DM '
#                                        'has an increased risk of developing '
#                                        'fractures, even in those with '
#                                        'initially normal bone density scores, '
#                                        'further illustrating the correlation '
#                                        'between DM and bone health. '
#                                        'Additionally, multiple risk factors, '
#                                        'including obesity, metabolic syndrome, '
#                                        'hypertension, estrogen-based hormone '
#                                        'therapy, and hyperuricemia, in '
#                                        'menopausal women can lead to the '
#                                        'development and exacerbation of OA. It '
#                                        'is discovered that these variables '
#                                        'have a direct or indirect impact, '
#                                        'frequently causing inflammation and '
#                                        'hormonal changes, which contribute to '
#                                        'the intricate interaction between DM '
#                                        'and OA. The management of OA and DM in '
#                                        'women\xa0thus calls for a '
#                                        'multi-faceted management plan '
#                                        'including glycemic control, weight '
#                                        'control, exercise, and specialized '
#                                        'pain management methods catering to '
#                                        'the specific requirements of the '
#                                        'patients. Regularly screening for OA '
#                                        'should be implemented for menopausal '
#                                        'women with DM and utmost care should '
#                                        'be provided by healthcare '
#                                        'professionals. Regular monitoring of '
#                                        'joint health and early management, '
#                                        'encouraging interdisciplinary '
#                                        'cooperation, putting preventative '
#                                        'measures into place, and creating '
#                                        'individualized treatment programs are '
#                                        'essential. A thorough understanding of '
#                                        'the link between DM and OA will '
#                                        'ultimately lead to improved health '
#                                        'outcomes and a better future for these '
#                                        'individuals.',
#                            'Authors': "['Shukla R; Singh S; Kamath S; Shah U; "
#                                       'Patel S; Kherajani K; Gupta A; Shaw P; '
#                                       "Unnithan V; Kaithathara S; Gharde P']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Interplay Between Diabetes Mellitus and '
#                                     'the Occurrence of Osteoarthritis and '
#                                     'Associated Conditions in Women of '
#                                     'Menopausal Age.'},
#               'score': 0.911242783,
#               'values': []},
#              {'id': '306',
#               'metadata': {'Abstract': "Adult-onset diabetes increases one's "
#                                        'risk of neurodegenerative disease '
#                                        "including Alzheimer's disease (AD); "
#                                        'however, the risk associated with '
#                                        'youth-onset diabetes (Y-DM) remains '
#                                        'underexplored. We quantified plasma '
#                                        'biomarkers of neurodegeneration and AD '
#                                        'in participants with Y-DM from the '
#                                        'SEARCH cohort at adolescence and young '
#                                        'adulthood (Type 1, n = 25; Type 2, n = '
#                                        '25; 59% female; adolescence, age = 15 '
#                                        'y/o [2.6]; adulthood, age = 27.4 y/o '
#                                        '[2.2]), comparing them with controls '
#                                        '(adolescence, n = 25, age = 14.8 y/o '
#                                        '[2.7]; adulthood, n = 21, age = 24.9 '
#                                        'y/o [2.8]). Plasma biomarkers, '
#                                        'including glial fibrillary acidic '
#                                        'protein (GFAP), neurofilament light '
#                                        'chain protein (NfL), phosphorylated '
#                                        'tau-181 (pTau181), and amyloid beta '
#                                        '(Aβ40, Aβ42), were measured via Simoa. '
#                                        'A subset of participants (n = 7; age = '
#                                        '27.5 y/o [5.7]) and six controls (age '
#                                        '= 25.1 y/o [4.5]) underwent PET scans '
#                                        'to quantify brain amyloid and tau '
#                                        'densities in AD sensitive brain '
#                                        'regions. Y-DM adolescents exhibited '
#                                        'lower plasma levels of Aβ40, Aβ42, and '
#                                        'GFAP, and higher pTau181 compared to '
#                                        'controls (<i>p</i> < 0.05), a pattern '
#                                        'persisting into adulthood (<i>p</i> < '
#                                        '0.001). All biomarkers showed '
#                                        'significant increases from adolescence '
#                                        'to adulthood in Y-DM (<i>p</i> < '
#                                        '0.01), though no significant '
#                                        'differences in brain amyloid or tau '
#                                        'were noted between Y-DM and controls '
#                                        'in adulthood. Preliminary evidence '
#                                        'suggests that preclinical AD '
#                                        'neuropathology is present in young '
#                                        'people with Y-DM, indicating a '
#                                        'potential increased risk of '
#                                        'neurodegenerative diseases.',
#                            'Authors': "['Shapiro ALB; Coughlan C; Bettcher BM; "
#                                       'Pauley ME; Kim J; Bjornstad P; Rajic B; '
#                                       'Truong J; Bell C; Choi YJ; Walker KA; '
#                                       'Potter H; Liese AD; Dabelea D; Whitlow '
#                                       "CT']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Biomarkers of Neurodegeneration and '
#                                     "Alzheimer's Disease Neuropathology in "
#                                     'Adolescents and Young Adults with '
#                                     'Youth-Onset Type 1 or Type 2 Diabetes: A '
#                                     'Proof-of-Concept Study.'},
#               'score': 0.910426557,
#               'values': []},
#              {'id': '191',
#               'metadata': {'Abstract': 'While NCDs are in rise globally, '
#                                        'tribal and rural populations residing '
#                                        'near to reserve forests with limited '
#                                        'exposure to modern lifestyles may bear '
#                                        'a unique burden. This study '
#                                        'investigates the prevalence and risk '
#                                        'factors of hypertension, diabetes, and '
#                                        'dyslipidemia among these communities. '
#                                        'We conducted a cross-sectional study '
#                                        'between 2018 and 2020 in the '
#                                        'forest-dwelling population of '
#                                        'Chamarajanagar, India. Using '
#                                        'multistage stratified sampling based '
#                                        'on caste and remoteness, we enrolled '
#                                        '608 participants aged over 18 years, '
#                                        'including 259 non-tribal and 349 '
#                                        'tribal individuals. Data collection '
#                                        'includes the administration of STEPS '
#                                        'questionnaire and measurement of '
#                                        'fasting blood sugar, lipid levels, and '
#                                        'blood pressure. The prevalence of '
#                                        'diabetes, hypertension, and '
#                                        'dyslipidemia were 4.6%, 28.8%, and '
#                                        '85.7%, respectively, among the study '
#                                        'population. We also found abnormal '
#                                        'levels of low-density lipoprotein '
#                                        '(LDL), high-density lipoprotein (HDL), '
#                                        'Triglycerides (TGA), Total cholesterol '
#                                        '(TC), and very low-density lipoprotein '
#                                        '(VLDL)in 4.9%, 82.4%, 22.7%, 5.8%, and '
#                                        '7.4% of participants, respectively. '
#                                        'Significant differences were observed '
#                                        'in diabetes, LDL abnormality, TGA '
#                                        'abnormality, VLDL abnormality, and TC '
#                                        'abnormality, but not in hypertension, '
#                                        'dyslipidemia, or HDL abnormality, '
#                                        'across the Socio Geographic '
#                                        'Discrimination Index. We found a '
#                                        'significant difference in diabetes and '
#                                        'HDL abnormality, but not in '
#                                        'hypertension, dyslipidemia, LDL '
#                                        'abnormality, TGA abnormality, TC '
#                                        'abnormality, or VLDL abnormality, '
#                                        'between tribal and non-tribal '
#                                        'populations living in the '
#                                        'forest-dwelling area. Waist '
#                                        'circumference was a significant '
#                                        'independent predictor of diabetes '
#                                        'among tribal participants, while '
#                                        'wealth index, age, and waist '
#                                        'circumference were significant '
#                                        'predictors of hypertension. There were '
#                                        'no significant predictors for '
#                                        'dyslipidemia among tribal '
#                                        'participants. Our study suggests that '
#                                        'tribal population living in a remote '
#                                        'area are at a lower risk of developing '
#                                        'diabetes compared to non-tribal '
#                                        'populations living in the same '
#                                        'geographic area. However, the '
#                                        'prevalence of hypertension and '
#                                        'dyslipidemia among tribal populations '
#                                        'remains high and comparable to that of '
#                                        'the general population.',
#                            'Authors': "['Mallikarjuna Majgi S; Channa Basappa "
#                                       'Y; Belagihalli Manjegowda S; Nageshappa '
#                                       "S; Suresh H; Babu GR; Srinivas PN']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Prevalence of dyslipidemia, hypertension '
#                                     'and diabetes among tribal and rural '
#                                     'population in a south Indian forested '
#                                     'region.'},
#               'score': 0.910385132,
#               'values': []},
#              {'id': '450',
#               'metadata': {'Abstract': 'Studies have suggested that Vitamin D '
#                                        'deficiency is associated with the '
#                                        'occurrence of both type 1 and type 2 '
#                                        'diabetes, and that vitamin D-binding '
#                                        'proteins (VDBP) are necessary for '
#                                        'metabolic stress in pancreatic '
#                                        'α-cells. However, the causal '
#                                        'relationship between serum '
#                                        '25-hydroxyvitamin D [25(OH)D] levels, '
#                                        'VDBP, and the risk of diabetes '
#                                        'mellitus (DM) remains unclear. '
#                                        'Mendelian randomization (MR) was used '
#                                        'to investigate the causal relationship '
#                                        'between 25(OH)D, VDBP, and DM. '
#                                        'Relevant recent data were downloaded '
#                                        'from the NHGRI-EBI Catalog of '
#                                        'published genome-wide association '
#                                        'studies (GWAS) and filtered for single '
#                                        'nucleotide polymorphisms (SNPs). We '
#                                        'used multiple MR methods, including '
#                                        'inverse variance weighting (IVW), and '
#                                        'performed sensitivity analyses to '
#                                        'detect whether pleiotropy or '
#                                        'heterogeneity biased the results. '
#                                        'There was a causal relationship '
#                                        'between genetically predicted VDBP '
#                                        'levels and serum 25(OH)D levels, and '
#                                        'serum 25(OH)D levels increased with '
#                                        'increasing VDBP levels (IVW: β\u2005'
#                                        '=\u20050.111, OR\u2005=\u20051.117, '
#                                        '95% CI:1.076-1.162, P\u2005=\u2005'
#                                        '1.41\u2005×\u200510-8). There was no '
#                                        'causal relationship between the '
#                                        'genetically predicted VDBP levels, '
#                                        'serum 25(OH)D levels, and DM (VDBP: '
#                                        'IVW β:0.001, OR:1.001, 95% '
#                                        'CI:0.998-1.003, P\u2005>\u2005.05; '
#                                        '25(OH)D: IVW β: -0.009, OR:0.991, 95% '
#                                        'CI:0.982-1.001, P\u2005=\u2005.068). '
#                                        'Sensitivity analysis indicated that '
#                                        'horizontal pleiotropy was unlikely to '
#                                        'bias causality in this study. MR '
#                                        'analysis results demonstrated a '
#                                        'positive causal relationship between '
#                                        'VDBP levels and serum 25(OH)D levels '
#                                        'in the European population. The '
#                                        '25(OH)D and VDBP levels were not '
#                                        'causally related to an increased risk '
#                                        'of diabetes.',
#                            'Authors': "['Zhao X; Li B; Li X; Ding Y; Zhang Y']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Association of serum 25-hydroxyvitamin D '
#                                     'levels, vitamin D-binding protein levels, '
#                                     'and diabetes mellitus: Two-sample '
#                                     'Mendelian randomization.'},
#               'score': 0.908076644,
#               'values': []},
#              {'id': '146',
#               'metadata': {'Abstract': 'The association between type 2 '
#                                        'diabetes mellitus (T2DM), lifestyle '
#                                        'factors, and the risk of osteoporosis '
#                                        '(OP) is well-established. However, the '
#                                        'impact of a healthy lifestyle on '
#                                        'diabetes-related osteoporosis needs '
#                                        'further investigation. Our objective '
#                                        'was to explore if a combination of '
#                                        'healthy lifestyle factors could '
#                                        'mitigate the risk of OP in individuals '
#                                        'with type 2 diabetes. This '
#                                        'longitudinal analysis included 237,725 '
#                                        'middle-aged and older participants. An '
#                                        'overall lifestyle score, ranging from '
#                                        '0 to 7, was calculated by assigning a '
#                                        'point for each of the seven healthy '
#                                        'lifestyle factors, including no '
#                                        'current smoking, non-excessive alcohol '
#                                        'consumption, regular physical '
#                                        'activity, healthy diet, adequate sleep '
#                                        'duration, less sedentary behavior, and '
#                                        'adequate sunshine exposure. During a '
#                                        'median follow-up 12.21 years, 5760 OP '
#                                        'cases were documented. Participants '
#                                        'with T2DM showed a higher risk of OP '
#                                        'than those without diabetes. Compared '
#                                        'with participants without diabetes who '
#                                        'had a lifestyle score of 6-7, the '
#                                        'hazard ratios (HRs) for OP were 1.58 '
#                                        '(95% CI 1.23-2.03), 1.62 (95% CI '
#                                        '1.16-2.25), and 2.58 (95% CI '
#                                        '1.64-4.05) for participants with T2DM '
#                                        'who had a lifestyle score of 4, 3, and '
#                                        '0-2, respectively. There was a graded '
#                                        'association between higher lifestyle '
#                                        'scores and lower risks of incident OP '
#                                        'among participants without diabetes as '
#                                        'well as among those with T2DM. We '
#                                        'estimated that the population '
#                                        'attributable fraction for not adhering '
#                                        'to 6-7 lifestyle behaviors was 15.7%. '
#                                        'Participants with T2DM who adhered to '
#                                        'a variety of healthy lifestyle factors '
#                                        'demonstrated a substantially reduced '
#                                        'risk of developing OP.',
#                            'Authors': "['Chen Y; Miao Y; Zhang Q']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Association of combined healthy lifestyle '
#                                     'factors with incident osteoporosis in '
#                                     'patients with and without type 2 '
#                                     'diabetes.'},
#               'score': 0.907021046,
#               'values': []},
#              {'id': '701',
#               'metadata': {'Abstract': 'The aim of this study was to assess '
#                                        'the extent of nondisclosure of type 1 '
#                                        'diabetes in adolescents and '
#                                        'investigate its association with '
#                                        'several psychosocial parameters and '
#                                        'clinical outcomes. This was a '
#                                        'cross-sectional study based on data '
#                                        'collected from 69 adolescents with '
#                                        'type 1 diabetes who were 12-18 years '
#                                        'of age and followed at our diabetes '
#                                        'clinic. The degree of disclosure, '
#                                        'demographics, diabetes management, and '
#                                        'psychosocial issues were assessed via '
#                                        'questionnaires. Clinical parameters '
#                                        'were derived from medical records. '
#                                        'Associations between nondisclosure '
#                                        'status and clinical and psychosocial '
#                                        'study variables were assessed. '
#                                        'Fifty-three participants (77%) '
#                                        'reported some extent of nondisclosure. '
#                                        'Nondisclosure was associated with low '
#                                        'self-esteem, reduced friend support, '
#                                        'and increased diabetes-related '
#                                        'worries. Nondisclosure was also found '
#                                        'to be associated with diminished '
#                                        'self-care behaviors related to insulin '
#                                        'administration and with elevated A1C. '
#                                        'Our results demonstrate that '
#                                        'nondisclosure of type 1 diabetes in '
#                                        'adolescents may be more common than '
#                                        'initially recognized and is likely '
#                                        'associated with unfavorable '
#                                        'psychological outcomes and reduced '
#                                        'self-care and diabetes management. Our '
#                                        'results emphasize the importance of '
#                                        'social interactions and disclosure in '
#                                        'adolescents and may serve as a '
#                                        'potential stepping stone to address '
#                                        'other social barriers hindering '
#                                        'diabetes management.',
#                            'Authors': "['Nir J; Liberman A; Yackobovitch-Gavan "
#                                       "M; Fraser D; Phillip M; Oron T']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Nondisclosure of Type 1 Diabetes in '
#                                     'Adolescence: A Single-Center Experience.'},
#               'score': 0.906809866,
#               'values': []},
#              {'id': '1367',
#               'metadata': {'Abstract': 'Diabetes, a chronic condition '
#                                        'affecting various organs, is '
#                                        'frequently associated with abnormal '
#                                        'lipid metabolism, notably increased '
#                                        'cholesterol and triglyceride levels. '
#                                        'These lipid abnormalities are closely '
#                                        'linked to the development and '
#                                        'advancement of cardiovascular disease '
#                                        '(CVD). Although regular physical '
#                                        'activity (PA) has consistently shown '
#                                        'benefits in reducing CVD risk in the '
#                                        'general population, its precise '
#                                        'influence on CVD risk among diabetic '
#                                        'patients remains uncertain, '
#                                        'particularly regarding dose-response '
#                                        'relationships. This study aimed to '
#                                        'summarize the evidence from '
#                                        'prospective studies on the association '
#                                        'between PA and CVD morbidity and '
#                                        'mortality in individuals with '
#                                        'diabetes, and to explore the optimal '
#                                        'levels for public health '
#                                        'recommendation. We systematically '
#                                        'reviewed prospective cohort studies in '
#                                        'PubMed, EMBASE, and Web of Science up '
#                                        'to December 2022, with inclusion '
#                                        'criteria specifying the studies '
#                                        'published in English and included '
#                                        'adult participants diagnosed with '
#                                        'diabetes. A random-effects model was '
#                                        'used to pool the relative risk (RR) '
#                                        'with the corresponding 95% confidence '
#                                        'interval (CI) comparing the highest '
#                                        'with the lowest PA categories in each '
#                                        'study for qualitative evaluation. In '
#                                        'addition, linear and spline regression '
#                                        'analyses were used to estimate '
#                                        'dose-response associations. The '
#                                        'meta-analysis included 12 prospective '
#                                        'cohort studies, involving a total of '
#                                        '109,820 participants with diabetes. '
#                                        'The combined results revealed that '
#                                        'higher levels of PA were associated '
#                                        'with a reduced risk of CVD. The RR of '
#                                        'CVD for the highest compared with the '
#                                        'lowest PA category was 0.62 (95% CI, '
#                                        '0.51-0.73). In addition, there were '
#                                        'four studies describing leisure-time '
#                                        'physical activity (LTPA) and the '
#                                        'pooled RR was 0.68 (95% CI, 0.52-0.83) '
#                                        'for the highest versus the lowest '
#                                        'activity. The linear regression model '
#                                        'revealed that each 10 MET-h/week of '
#                                        'incrementally higher PA was associated '
#                                        'with a 19.0% (95% CI, 11.6%-25.7%) and '
#                                        'a 6.9% (95% CI, 4.5%-9.3%) reduction '
#                                        'in CVD morbidity and mortality. '
#                                        'Additionally, spline regression curves '
#                                        'showed nonlinear relationships between '
#                                        'PA levels and the risk of CVD and CVD '
#                                        'mortality (both P-nonlinearity '
#                                        '<0.001), with a limited reduction in '
#                                        'CVD risk and some further reduction in '
#                                        'CVD mortality above 20 MET-h per week '
#                                        'of PA levels. For patients with '
#                                        'diabetes, especially type 2 diabetes, '
#                                        'there was a dose-response relationship '
#                                        'between increased PA and reduced risk '
#                                        'of CVD morbidity and mortality. The '
#                                        'observed PA threshold is consistent '
#                                        'with the recommended level for the '
#                                        'general population. Gradually moving '
#                                        'from inactivity to a '
#                                        'guideline-recommended PA level could '
#                                        'therefore significantly reduce the '
#                                        'burden of CVD in patients with '
#                                        'diabetes.',
#                            'Authors': "['Chen Y; Jin X; Chen G; Wang R; Tian "
#                                       "H']",
#                            'Publication Year': 2024.0,
#                            'Title': 'Dose-response relationship between '
#                                     'physical activity and the morbidity and '
#                                     'mortality of cardiovascular disease among '
#                                     'individuals with diabetes: A '
#                                     'meta-analysis of prospective cohort '
#                                     'studies.'},
#               'score': 0.906627655,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %%
for match in res['matches']:
    print(f"{match['score']:.2f}: {match['metadata']['Title']}")
    print(f"{match['score']:.2f}: {match['metadata']['Abstract']}")
    print(f"{match['score']:.2f}: {match['metadata']['Authors']}")
# Out:
# 0.92: Dietary Modulations in Preventing Cardiometabolic Risk in Individuals with Type 2 Diabetes.
# 0.92: Type 2 diabetes mellitus (T2DM) is a complex health issue include obesity, high cholesterol, high blood pressure, and chronic inflammation that increase the risk of cardiovascular diseases (CVDs). CVDs are of great concern in the disease progression and prognosis of T2DM. This review is a comprehensive examination of the literature on the relationship between T2DM and cardiovascular risk, nutrition-related cardiometabolic risk (CMR) factors, and impact of dietary modulations on CMR. In recent years the researches has been focus on the importance of a comprehensive treatment approach like dietary modulations to address multiple cardiovascular risk reductions, including hypertension and dyslipidemia. Modulation of dietary patterns are the most promising interventions to prevent CMR factors and T2DM via affecting the body weight, glucose control, and microbial diversity of individuals. Current evidence suggests that high-quality dietary patterns such as the Dietary Approaches to Stop Hypertension (DASH) eating plan and the Mediterranean diet is important in the metabolic control processes of T2DM with anti-inflammatory and antioxidant compounds, glucagon-like peptide agonist compounds, and intestinal microbiota changes. Nutrition plays a critical role in preventing and improving CVD outcomes in patients with T2DM. Dietary modulations should be planned considering individual differences in responses to dietary composition and nutritional changes, personal preferences, eating behaviors and gut microbiota differences.
# 0.92: ['Dal N; Bilici S']
# 0.91: Regional and rural-urban patterns in the prevalence of diagnosed hypertension among older U.S. adults with diabetes, 2005-2017.
# 0.91: Hypertension prevalence among the overall US adult population has been relatively stable during the last two decades. However, whether this stabilization has occurred across rural-urban communities and across different geographic regions is unknown, particularly among older adults with diabetes who are likely to have concomitant cardiovascular risk factors. This serial cross-sectional analysis used the 5% national sample of Medicare administrative claims data (n = 3,516,541) to examine temporal trends (2005-2017) in diagnosed hypertension among older adults with diabetes, across urban-rural communities and US census regions (Northeast, Midwest, South, and West). Joinpoint regression was used to obtain annual percent change (APC) in hypertension prevalence across rural-urban communities and geographic regions, and multivariable adjusted regression was used to assess associations between rural-urban communities and hypertension prevalence. The APC in the prevalence of hypertension was higher during 2005-2010, and there was a slowdown in the increase during 2011-2017 across all regions, with significant variations across rural-urban communities within each of the regions. In the regression analysis, in the adjusted model, older adults living in non-core (most rural) areas in the Midwest (PR = 0.988, 95% CI: 0.981-0.995) and West (PR = 0.935, 95% CI: 0.923-0.946) had lower hypertension prevalence than their regional counterparts living in large central metro areas. Although the magnitudes of these associations are small, differences in hypertension prevalence across rural-urban areas and geographic regions may have implications for targeted interventions to improve chronic disease prevention and management.
# 0.91: ['Uddin J; Zhu S; Malla G; Levitan EB; Rolka DB; Carson AP; Long DL']
# 0.91: Global status and trends of metabolomics in diabetes: A literature visualization knowledge graph study.
# 0.91: Diabetes is a metabolic disease characterized by hyperglycemia, which has increased the global medical burden and is also the main cause of death in most countries. To understand the knowledge structure of global development status, research focus, and future trend of the relationship between diabetes and metabolomics in the past 20 years. The articles about the relationship between diabetes and metabolomics in the Web of Science Core Collection were retrieved from 2002 to October 23, 2023, and the relevant information was analyzed using CiteSpace6.2.2R (CiteSpace), VOSviewer6.1.18 (VOSviewer), and Bibliometrix software under R language. A total of 3123 publications were included from 2002 to 2022. In the past two decades, the number of publications and citations in this field has continued to increase. The United States, China, Germany, the United Kingdom, and other relevant funds, institutions, and authors have significantly contributed to this field. <i>Scientific Reports</i> and <i>PLoS One</i> are the journals with the most publications and the most citations. Through keyword co-occurrence and cluster analysis, the closely related keywords are "insulin resistance", "risk", "obesity", "oxidative stress", "metabolomics", "metabolites" and "biomarkers". Keyword clustering included cardiovascular disease, gut microbiota, metabonomics, diabetic nephropathy, molecular docking, gestational diabetes mellitus, oxidative stress, and insulin resistance. Burst detection analysis of keyword depicted that "Gene", "microbiota", "validation", "kidney disease", "antioxidant activity", "untargeted metabolomics", "management", and "accumulation" are knowledge frontiers in recent years. The relationship between metabolomics and diabetes is receiving extensive attention. Diabetic nephropathy, diabetic cardiovascular disease, and kidney disease are key diseases for future research in this field. Gut microbiota, molecular docking, and untargeted metabolomics are key research directions in the future. Antioxidant activity, gene, validation, mass spectrometry, management, and accumulation are at the forefront of knowledge frontiers in this field.
# 0.91: ['Li H; Li L; Huang QQ; Yang SY; Zou JJ; Xiao F; Xiang Q; Liu X; Yu R']
# 0.91: Interplay Between Diabetes Mellitus and the Occurrence of Osteoarthritis and Associated Conditions in Women of Menopausal Age.
# 0.91: Osteoarthritis (OA) and diabetes mellitus (DM) have long-term deleterious chronic effects and are among the most prevalent chronic disorders. DM and its associated factors, such as hyperglycemia, have a significant contribution to the pathophysiology of OA, particularly in post-menopausal women. Women who have uncontrolled diabetes (DM) are more prone to develop osteoarthritis (OA), which may be exacerbated by poor glycemic control. Furthermore, this category of female patients with DM has an increased risk of developing fractures, even in those with initially normal bone density scores, further illustrating the correlation between DM and bone health. Additionally, multiple risk factors, including obesity, metabolic syndrome, hypertension, estrogen-based hormone therapy, and hyperuricemia, in menopausal women can lead to the development and exacerbation of OA. It is discovered that these variables have a direct or indirect impact, frequently causing inflammation and hormonal changes, which contribute to the intricate interaction between DM and OA. The management of OA and DM in women thus calls for a multi-faceted management plan including glycemic control, weight control, exercise, and specialized pain management methods catering to the specific requirements of the patients. Regularly screening for OA should be implemented for menopausal women with DM and utmost care should be provided by healthcare professionals. Regular monitoring of joint health and early management, encouraging interdisciplinary cooperation, putting preventative measures into place, and creating individualized treatment programs are essential. A thorough understanding of the link between DM and OA will ultimately lead to improved health outcomes and a better future for these individuals.
# 0.91: ['Shukla R; Singh S; Kamath S; Shah U; Patel S; Kherajani K; Gupta A; Shaw P; Unnithan V; Kaithathara S; Gharde P']
# 0.91: Biomarkers of Neurodegeneration and Alzheimer's Disease Neuropathology in Adolescents and Young Adults with Youth-Onset Type 1 or Type 2 Diabetes: A Proof-of-Concept Study.
# 0.91: Adult-onset diabetes increases one's risk of neurodegenerative disease including Alzheimer's disease (AD); however, the risk associated with youth-onset diabetes (Y-DM) remains underexplored. We quantified plasma biomarkers of neurodegeneration and AD in participants with Y-DM from the SEARCH cohort at adolescence and young adulthood (Type 1, n = 25; Type 2, n = 25; 59% female; adolescence, age = 15 y/o [2.6]; adulthood, age = 27.4 y/o [2.2]), comparing them with controls (adolescence, n = 25, age = 14.8 y/o [2.7]; adulthood, n = 21, age = 24.9 y/o [2.8]). Plasma biomarkers, including glial fibrillary acidic protein (GFAP), neurofilament light chain protein (NfL), phosphorylated tau-181 (pTau181), and amyloid beta (Aβ40, Aβ42), were measured via Simoa. A subset of participants (n = 7; age = 27.5 y/o [5.7]) and six controls (age = 25.1 y/o [4.5]) underwent PET scans to quantify brain amyloid and tau densities in AD sensitive brain regions. Y-DM adolescents exhibited lower plasma levels of Aβ40, Aβ42, and GFAP, and higher pTau181 compared to controls (<i>p</i> < 0.05), a pattern persisting into adulthood (<i>p</i> < 0.001). All biomarkers showed significant increases from adolescence to adulthood in Y-DM (<i>p</i> < 0.01), though no significant differences in brain amyloid or tau were noted between Y-DM and controls in adulthood. Preliminary evidence suggests that preclinical AD neuropathology is present in young people with Y-DM, indicating a potential increased risk of neurodegenerative diseases.
# 0.91: ['Shapiro ALB; Coughlan C; Bettcher BM; Pauley ME; Kim J; Bjornstad P; Rajic B; Truong J; Bell C; Choi YJ; Walker KA; Potter H; Liese AD; Dabelea D; Whitlow CT']
# 0.91: Prevalence of dyslipidemia, hypertension and diabetes among tribal and rural population in a south Indian forested region.
# 0.91: While NCDs are in rise globally, tribal and rural populations residing near to reserve forests with limited exposure to modern lifestyles may bear a unique burden. This study investigates the prevalence and risk factors of hypertension, diabetes, and dyslipidemia among these communities. We conducted a cross-sectional study between 2018 and 2020 in the forest-dwelling population of Chamarajanagar, India. Using multistage stratified sampling based on caste and remoteness, we enrolled 608 participants aged over 18 years, including 259 non-tribal and 349 tribal individuals. Data collection includes the administration of STEPS questionnaire and measurement of fasting blood sugar, lipid levels, and blood pressure. The prevalence of diabetes, hypertension, and dyslipidemia were 4.6%, 28.8%, and 85.7%, respectively, among the study population. We also found abnormal levels of low-density lipoprotein (LDL), high-density lipoprotein (HDL), Triglycerides (TGA), Total cholesterol (TC), and very low-density lipoprotein (VLDL)in 4.9%, 82.4%, 22.7%, 5.8%, and 7.4% of participants, respectively. Significant differences were observed in diabetes, LDL abnormality, TGA abnormality, VLDL abnormality, and TC abnormality, but not in hypertension, dyslipidemia, or HDL abnormality, across the Socio Geographic Discrimination Index. We found a significant difference in diabetes and HDL abnormality, but not in hypertension, dyslipidemia, LDL abnormality, TGA abnormality, TC abnormality, or VLDL abnormality, between tribal and non-tribal populations living in the forest-dwelling area. Waist circumference was a significant independent predictor of diabetes among tribal participants, while wealth index, age, and waist circumference were significant predictors of hypertension. There were no significant predictors for dyslipidemia among tribal participants. Our study suggests that tribal population living in a remote area are at a lower risk of developing diabetes compared to non-tribal populations living in the same geographic area. However, the prevalence of hypertension and dyslipidemia among tribal populations remains high and comparable to that of the general population.
# 0.91: ['Mallikarjuna Majgi S; Channa Basappa Y; Belagihalli Manjegowda S; Nageshappa S; Suresh H; Babu GR; Srinivas PN']
# 0.91: Association of serum 25-hydroxyvitamin D levels, vitamin D-binding protein levels, and diabetes mellitus: Two-sample Mendelian randomization.
# 0.91: Studies have suggested that Vitamin D deficiency is associated with the occurrence of both type 1 and type 2 diabetes, and that vitamin D-binding proteins (VDBP) are necessary for metabolic stress in pancreatic α-cells. However, the causal relationship between serum 25-hydroxyvitamin D [25(OH)D] levels, VDBP, and the risk of diabetes mellitus (DM) remains unclear. Mendelian randomization (MR) was used to investigate the causal relationship between 25(OH)D, VDBP, and DM. Relevant recent data were downloaded from the NHGRI-EBI Catalog of published genome-wide association studies (GWAS) and filtered for single nucleotide polymorphisms (SNPs). We used multiple MR methods, including inverse variance weighting (IVW), and performed sensitivity analyses to detect whether pleiotropy or heterogeneity biased the results. There was a causal relationship between genetically predicted VDBP levels and serum 25(OH)D levels, and serum 25(OH)D levels increased with increasing VDBP levels (IVW: β = 0.111, OR = 1.117, 95% CI:1.076-1.162, P = 1.41 × 10-8). There was no causal relationship between the genetically predicted VDBP levels, serum 25(OH)D levels, and DM (VDBP: IVW β:0.001, OR:1.001, 95% CI:0.998-1.003, P > .05; 25(OH)D: IVW β: -0.009, OR:0.991, 95% CI:0.982-1.001, P = .068). Sensitivity analysis indicated that horizontal pleiotropy was unlikely to bias causality in this study. MR analysis results demonstrated a positive causal relationship between VDBP levels and serum 25(OH)D levels in the European population. The 25(OH)D and VDBP levels were not causally related to an increased risk of diabetes.
# 0.91: ['Zhao X; Li B; Li X; Ding Y; Zhang Y']
# 0.91: Association of combined healthy lifestyle factors with incident osteoporosis in patients with and without type 2 diabetes.
# 0.91: The association between type 2 diabetes mellitus (T2DM), lifestyle factors, and the risk of osteoporosis (OP) is well-established. However, the impact of a healthy lifestyle on diabetes-related osteoporosis needs further investigation. Our objective was to explore if a combination of healthy lifestyle factors could mitigate the risk of OP in individuals with type 2 diabetes. This longitudinal analysis included 237,725 middle-aged and older participants. An overall lifestyle score, ranging from 0 to 7, was calculated by assigning a point for each of the seven healthy lifestyle factors, including no current smoking, non-excessive alcohol consumption, regular physical activity, healthy diet, adequate sleep duration, less sedentary behavior, and adequate sunshine exposure. During a median follow-up 12.21 years, 5760 OP cases were documented. Participants with T2DM showed a higher risk of OP than those without diabetes. Compared with participants without diabetes who had a lifestyle score of 6-7, the hazard ratios (HRs) for OP were 1.58 (95% CI 1.23-2.03), 1.62 (95% CI 1.16-2.25), and 2.58 (95% CI 1.64-4.05) for participants with T2DM who had a lifestyle score of 4, 3, and 0-2, respectively. There was a graded association between higher lifestyle scores and lower risks of incident OP among participants without diabetes as well as among those with T2DM. We estimated that the population attributable fraction for not adhering to 6-7 lifestyle behaviors was 15.7%. Participants with T2DM who adhered to a variety of healthy lifestyle factors demonstrated a substantially reduced risk of developing OP.
# 0.91: ['Chen Y; Miao Y; Zhang Q']
# 0.91: Nondisclosure of Type 1 Diabetes in Adolescence: A Single-Center Experience.
# 0.91: The aim of this study was to assess the extent of nondisclosure of type 1 diabetes in adolescents and investigate its association with several psychosocial parameters and clinical outcomes. This was a cross-sectional study based on data collected from 69 adolescents with type 1 diabetes who were 12-18 years of age and followed at our diabetes clinic. The degree of disclosure, demographics, diabetes management, and psychosocial issues were assessed via questionnaires. Clinical parameters were derived from medical records. Associations between nondisclosure status and clinical and psychosocial study variables were assessed. Fifty-three participants (77%) reported some extent of nondisclosure. Nondisclosure was associated with low self-esteem, reduced friend support, and increased diabetes-related worries. Nondisclosure was also found to be associated with diminished self-care behaviors related to insulin administration and with elevated A1C. Our results demonstrate that nondisclosure of type 1 diabetes in adolescents may be more common than initially recognized and is likely associated with unfavorable psychological outcomes and reduced self-care and diabetes management. Our results emphasize the importance of social interactions and disclosure in adolescents and may serve as a potential stepping stone to address other social barriers hindering diabetes management.
# 0.91: ['Nir J; Liberman A; Yackobovitch-Gavan M; Fraser D; Phillip M; Oron T']
# 0.91: Dose-response relationship between physical activity and the morbidity and mortality of cardiovascular disease among individuals with diabetes: A meta-analysis of prospective cohort studies.
# 0.91: Diabetes, a chronic condition affecting various organs, is frequently associated with abnormal lipid metabolism, notably increased cholesterol and triglyceride levels. These lipid abnormalities are closely linked to the development and advancement of cardiovascular disease (CVD). Although regular physical activity (PA) has consistently shown benefits in reducing CVD risk in the general population, its precise influence on CVD risk among diabetic patients remains uncertain, particularly regarding dose-response relationships. This study aimed to summarize the evidence from prospective studies on the association between PA and CVD morbidity and mortality in individuals with diabetes, and to explore the optimal levels for public health recommendation. We systematically reviewed prospective cohort studies in PubMed, EMBASE, and Web of Science up to December 2022, with inclusion criteria specifying the studies published in English and included adult participants diagnosed with diabetes. A random-effects model was used to pool the relative risk (RR) with the corresponding 95% confidence interval (CI) comparing the highest with the lowest PA categories in each study for qualitative evaluation. In addition, linear and spline regression analyses were used to estimate dose-response associations. The meta-analysis included 12 prospective cohort studies, involving a total of 109,820 participants with diabetes. The combined results revealed that higher levels of PA were associated with a reduced risk of CVD. The RR of CVD for the highest compared with the lowest PA category was 0.62 (95% CI, 0.51-0.73). In addition, there were four studies describing leisure-time physical activity (LTPA) and the pooled RR was 0.68 (95% CI, 0.52-0.83) for the highest versus the lowest activity. The linear regression model revealed that each 10 MET-h/week of incrementally higher PA was associated with a 19.0% (95% CI, 11.6%-25.7%) and a 6.9% (95% CI, 4.5%-9.3%) reduction in CVD morbidity and mortality. Additionally, spline regression curves showed nonlinear relationships between PA levels and the risk of CVD and CVD mortality (both P-nonlinearity <0.001), with a limited reduction in CVD risk and some further reduction in CVD mortality above 20 MET-h per week of PA levels. For patients with diabetes, especially type 2 diabetes, there was a dose-response relationship between increased PA and reduced risk of CVD morbidity and mortality. The observed PA threshold is consistent with the recommended level for the general population. Gradually moving from inactivity to a guideline-recommended PA level could therefore significantly reduce the burden of CVD in patients with diabetes.
# 0.91: ['Chen Y; Jin X; Chen G; Wang R; Tian H']
